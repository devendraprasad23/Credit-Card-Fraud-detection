# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
#training the Logistic Regression Model with Training Data
from sklearn.linear_model import LogisticRegression # make sure to import the necessary module

model = LogisticRegression() # define the model variable in the current scope
model.fit(X_train, Y_train)
from sklearn.metrics import accuracy_score

# %%
#loading the dataset to a pandas Dataframe
#loading the dataset to a pandas Dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv', on_bad_lines='skip') # skip lines with errors
# Out:
# <ipython-input-7-6280343b4fdc>:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   credit_card_data = pd.read_csv('/content/creditcard.csv', on_bad_lines='skip') # skip lines with errors

# %%
# first 5 rows of the dataFrame
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 255083  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 255084  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 255085  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 255086  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 255087  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 255083 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 255084  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 255085  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 255086  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 255087 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255088 entries, 0 to 255087
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    255088 non-null  float64
#  1   V1      255088 non-null  float64
#  2   V2      255088 non-null  float64
#  3   V3      255088 non-null  float64
#  4   V4      255088 non-null  float64
#  5   V5      255088 non-null  float64
#  6   V6      255088 non-null  float64
#  7   V7      255088 non-null  float64
#  8   V8      255088 non-null  float64
#  9   V9      255088 non-null  float64
#  10  V10     255088 non-null  object
#  11  V11     255087 non-null  float64
#  12  V12     255086 non-null  float64
#  13  V13     255086 non-null  float64
#  14  V14     255086 non-null  float64
#  15  V15     255086 non-null  float64
#  16  V16     255085 non-null  float64
#  17  V17     255085 non-null  float64
#  18  V18     255085 non-null  float64
#  19  V19     255085 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       1
# V12       2
# V13       2
# V14       2
# V15       2
# V16       3
# V17       3
# V18       3
# V19       3
# V20       3
# V21       3
# V22       3
# V23       4
# V24       4
# V25       4
# V26       5
# V27       5
# V28       5
# Amount    5
# Class     5
# dtype: int64

# %%
# distribution of legit transactions & fruad transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    254660
# 1.0       423
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unbalanced
#
# 0--> Normal Transaction
#
# 1-->fraud transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (254660, 31)
# (423, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    254660.000000
# mean         86.470305
# std         248.525667
# min           0.000000
# 25%           5.350000
# 50%          20.660000
# 75%          75.000000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     423.000000
# mean      124.969976
# std       266.541889
# min         0.000000
# 25%         1.000000
# 50%         7.570000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
#compare the values for both transactions
credit_card_data.groupby('Class').mean(numeric_only=True) # set numeric_only to True to only calculate the mean of numeric columns
# Out:
#                 Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    101711.881579  0.033815  0.006483 -0.063520 -0.022767  0.040774
# 1.0     87810.397163 -4.276283  3.400701 -6.668589  4.377175 -2.642163
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.008487  0.020277 -0.009494  0.029367  ... -0.007252  0.000005
# 1.0   -1.276407 -5.142759 -0.012933 -2.309489  ...  0.385635  0.604462
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0    0.009253  0.004731 -0.000706 -0.017152 -0.001698 -0.000295 -0.000590
# 1.0    0.049255 -0.008117 -0.152212 -0.001014  0.041191  0.158276  0.086922
#
#            Amount
# Class
# 0.0     86.470305
# 1.0    124.969976
#
# [2 rows x 29 columns]

# %% [markdown]
# Under-Sample

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactins and Fraud Tranasactions
#
# Number of transactions-->25

# %%
legit_sample = legit.sample(n=25)

# %% [markdown]
# Containing two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 13455    10262.0 -1.161678  1.014845  1.341105  0.219589 -0.399681 -0.792609
# 193359  143238.0 -0.905777  1.242481 -0.716030 -0.646550  0.479189 -0.939751
# 139260  119470.0 -0.643736 -0.178902 -0.279128 -0.806155  1.804098  1.499641
# 191141  142327.0 -0.679435  0.618923  1.194657 -0.425657 -2.250719  0.751678
# 104104   80542.0  1.104597 -0.277470  1.231644  0.634464 -1.254868 -0.380660
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 13455   0.060908  0.450452  0.744772  ... -0.290013 -0.735224  0.328666
# 193359  0.273707  0.552560 -0.567054  ...  0.407173  0.937074 -0.300562
# 139260  0.597049  0.239050  0.243199  ... -0.102520  0.244553  0.544099
# 191141 -0.570801 -3.343568 -0.617492  ...  2.325145 -2.408189  0.156442
# 104104 -0.761793  0.227249  0.548320  ...  0.134066  0.261670  0.036225
#
# ...

# %%
new_dataset
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 13455    10262.0 -1.161678  1.014845  1.341105  0.219589 -0.399681 -0.792609
# 193359  143238.0 -0.905777  1.242481 -0.716030 -0.646550  0.479189 -0.939751
# 139260  119470.0 -0.643736 -0.178902 -0.279128 -0.806155  1.804098  1.499641
# 191141  142327.0 -0.679435  0.618923  1.194657 -0.425657 -2.250719  0.751678
# 104104   80542.0  1.104597 -0.277470  1.231644  0.634464 -1.254868 -0.380660
# ...          ...       ...       ...       ...       ...       ...       ...
# 250144  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 250424  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 250430  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 251425  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 251955  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 1.0    423
# 0.0     25
# Name: count, dtype: int64

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 13455    10262.0 -1.161678  1.014845  1.341105  0.219589 -0.399681 -0.792609
# 193359  143238.0 -0.905777  1.242481 -0.716030 -0.646550  0.479189 -0.939751
# 139260  119470.0 -0.643736 -0.178902 -0.279128 -0.806155  1.804098  1.499641
# 191141  142327.0 -0.679435  0.618923  1.194657 -0.425657 -2.250719  0.751678
# 104104   80542.0  1.104597 -0.277470  1.231644  0.634464 -1.254868 -0.380660
# ...          ...       ...       ...       ...       ...       ...       ...
# 250144  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 250424  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 250430  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 251425  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 251955  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 13455     0.0
# 193359    0.0
# 139260    0.0
# 191141    0.0
# 104104    0.0
#          ...
# 250144    1.0
# 250424    1.0
# 250430    1.0
# 251425    1.0
# 251955    1.0
# Name: Class, Length: 448, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (448, 30) (358, 30) (90, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data:',training_data_accuracy)
# Out:
# Accuracy on Training data: 0.9581005586592178
